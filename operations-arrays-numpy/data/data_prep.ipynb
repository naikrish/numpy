# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('dataset.csv', decimal=',')

# %%
data
# Out:
#         ID                           Nombre                          Mail  \
# 0      NaN                              NaN                           NaN
# 1      NaN                              NaN                           NaN
# 2      1.0                              NaN  altamiranoevelyn22@gmail.com
# 3      2.0                              NaN         ana_chejo@hotmail.com
# 4      3.0                              NaN    barbara_arroyo@outlook.com
# ..     ...                              ...                           ...
# 196  200.0  PALACIOS SINCHE, ANDREA JAZMIN.                           NaN
# 197  201.0         PARRA, AGUSTINA SOLEDAD.                           NaN
# 198  202.0                     PONCE, IVAN.                           NaN
# 199  203.0          RODRIGUEZ, LUCIA BELEN.                           NaN
# 200  204.0                  ROJAS, MICAELA.                           NaN
#
#      SIMULADOR Competencia resolucion de problemas Unnamed: 5 Unnamed: 6  \
# ...

# %%
new_data = data.loc[:,'SIMULADOR':'Unnamed: 12'].iloc[2:].reset_index(drop=True)

# %%
new_data.dtypes
# Out:
# SIMULADOR                              float64
# Competencia resolucion de problemas     object
# Unnamed: 5                              object
# Unnamed: 6                              object
# Unnamed: 7                              object
# Unnamed: 8                              object
# Unnamed: 9                              object
# Unnamed: 10                             object
# Unnamed: 11                             object
# Unnamed: 12                             object
# dtype: object

# %%
new_data['Unnamed: 7'] = pd.to_numeric(new_data['Unnamed: 7'].str.replace(',', '.'))
new_data['Unnamed: 12'] = pd.to_numeric(new_data['Unnamed: 12'].str.replace(',', '.'))
new_data.apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2,67"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/g0/jqvp4xxs5pn4cds1xb9339xm0000gn/T/ipykernel_40884/1258620996.py in <module>
#       1 new_data['Unnamed: 7'] = pd.to_numeric(new_data['Unnamed: 7'].str.replace(',', '.'))
#       2 new_data['Unnamed: 12'] = pd.to_numeric(new_data['Unnamed: 12'].str.replace(',', '.'))
# ----> 3 new_data.apply(pd.to_numeric)
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# ...

# %%
new_data.to_csv('cleaned_dataset.csv', header=False)
